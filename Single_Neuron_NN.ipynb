# %%
import torch
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/gscdit/Breast-Cancer-Detection/refs/heads/master/data.csv'
df = pd.read_csv(url)
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.shape
# Out:
# (569, 33)

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df['Unnamed: 32'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 569 entries, 0 to 568
# Series name: Unnamed: 32
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
df.drop(columns=['id', 'Unnamed: 32'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
X = df.drop(columns=['diagnosis'])
Y = df['diagnosis']

X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
Y.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

# %%
X.shape, X_train.shape, X_test.shape
# Out:
# ((569, 30), (455, 30), (114, 30))

# %%
Y.shape, y_train.shape, y_test.shape
# Out:
# ((569,), (455,), (114,))

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
ss.fit(X_train)

X_train_scaled = ss.transform(X_train)
X_test_scaled = ss.transform(X_test)

type(X_train_scaled), type(X_test_scaled)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((455, 30), (114, 30))

# %%
X_train_scaled.mean()
# Out:
# np.float64(-3.9431217753719845e-17)

# %%
X_train_scaled.std()
# Out:
# np.float64(1.0)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(y_train)

y_train_encoded = le.transform(y_train)
y_test_encoded = le.transform(y_test)

type(y_train_encoded), type(y_test_encoded)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
y_train_encoded.shape, y_test_encoded.shape
# Out:
# ((455,), (114,))

# %% [markdown]
# ### Numpy to Tensors

# %%
X_train_tnsr = torch.from_numpy(X_train_scaled)
y_train_tnsr = torch.from_numpy(y_train_encoded)

type(X_train_tnsr), type(y_train_tnsr)
# Out:
# (torch.Tensor, torch.Tensor)

# %%
X_train_tnsr.shape, y_train_tnsr.shape
# Out:
# (torch.Size([455, 30]), torch.Size([455]))

# %% [markdown]
# ### Building a single Neuron Network

# %%
class SingleNN:
    def __init__(self, X):
        """X --> input feature with shape [m,n]
            m = no. of data
            n = no. of features
        """
        self.weights = torch.rand(X.shape[1], 1, dtype=torch.float64,requires_grad=True)
        self.bias = torch.zeros(1, dtype=torch.float64, requires_grad=True)

    def forward(self, X):
        """X --> input feature with shape [m,n]
            m = no. of data
            n = no. of features
        """
        z = torch.matmul(X, self.weights) + self.bias
        y_pred = torch.sigmoid(z)
        return y_pred

    def loss_function(self, y_pred, y):
        """
            y_pred --> predicted output generated by self.forward() method
            y      --> actual output

        Purpose: Difference between both the outputs
        """

        ## avoiding y_pred to be exactly 0 or 1 
        ## to avoid log(0) and log(1 - 1) = log(0)

        epsilon = 1e-7
        y_pred = torch.clamp(y_pred, epsilon, 1-epsilon)

        ## Calculate loss
        loss = -(y * torch.log(y_pred) + (1 - y)* torch.log(1 - y_pred)).mean() 
        return loss

# %% [markdown]
# ### Important Parameters

# %%
learning_rate = 0.1
epochs = 25

# %%
model = SingleNN(X_train_tnsr)

for i in range(epochs):
    y_pred = model.forward(X_train_tnsr)
    # print(y_pred.shape)

    loss = model.loss_function(y_pred, y_train_tnsr)
    # print(f'{i+1} epoch: {loss:.4f}')

    ## back propogation
    loss.backward()

    ## updating paramters (weights and bias)
    with torch.no_grad():
        model.weights -= (learning_rate* model.weights.grad)
        model.bias -= learning_rate* model.bias.grad

    ## intializing gradients(for both parameters) with zero after every epoch
    model.weights.grad.zero_()
    model.bias.grad.zero_()

    print(f'{i+1} epoch: {loss:.4f}')
# Out:
# 1 epoch: 3.8257
# 2 epoch: 3.7042
# 3 epoch: 3.5749
# 4 epoch: 3.4441
# 5 epoch: 3.3120
# 6 epoch: 3.1771
# 7 epoch: 3.0324
# 8 epoch: 2.8838
# 9 epoch: 2.7296
# 10 epoch: 2.5720
# 11 epoch: 2.4130
# 12 epoch: 2.2520
# 13 epoch: 2.0926
# 14 epoch: 1.9327
# 15 epoch: 1.7783
# 16 epoch: 1.6264
# 17 epoch: 1.4843
# 18 epoch: 1.3526
# 19 epoch: 1.2358
# 20 epoch: 1.1352
# 21 epoch: 1.0510
# 22 epoch: 0.9824
# 23 epoch: 0.9275
# 24 epoch: 0.8840
# 25 epoch: 0.8495

# %%
print(f'Best Parameters for a single neuron NN trained on 25 epochs:- ')
print(f'Weight:- {model.weights}')
print(f'Bias:- {model.bias}')
# Out:
# Best Parameters for a single neuron NN trained on 25 epochs:-
# Weight:- tensor([[ 0.2872],
#         [ 0.3951],
#         [ 0.4180],
#         [-0.3698],
#         [ 0.0781],
#         [ 0.1617],
#         [-0.2697],
#         [-0.3689],
#         [ 0.1599],
#         [ 0.3954],
#         [ 0.0431],
#         [ 0.1100],
#         [ 0.2314],
#         [-0.3219],
#         [ 0.3872],
#         [ 0.3350],
#         [-0.3511],
#         [-0.1603],
#         [ 0.2804],
#         [-0.1155],
#         [ 0.5133],
#         [ 0.1456],
#         [-0.3817],
#         [-0.4044],
#         [-0.0430],
#         [ 0.2273],
#         [ 0.3021],
#         [ 0.2015],
#         [ 0.1859],
#         [-0.2416]], dtype=torch.float64, requires_grad=True)
# Bias:- tensor([-0.1459], dtype=torch.float64, requires_grad=True)

# %% [markdown]
# ### Test dataset

# %%
X_test_tnsr = torch.from_numpy(X_test_scaled)
y_test_tnsr = torch.from_numpy(y_test_encoded)

type(X_test_tnsr), type(y_test_tnsr)
# Out:
# (torch.Tensor, torch.Tensor)

# %%
X_test_tnsr.shape, y_test_tnsr.shape
# Out:
# (torch.Size([114, 30]), torch.Size([114]))

# %%
with torch.no_grad():
    y_pred_test = model.forward(X_test_tnsr)

    preds = (y_pred_test > 0.5).int()
    actual = y_test_tnsr.int()

    accuracy = (preds == actual).float().mean()
    print(f'Accuracy on test set:- {accuracy* 100:.2f}%')
# Out:
# Accuracy on test set:- 52.71%
