# %%
import torch

# %%
x = torch.tensor(3.0, requires_grad=True)
x
# Out:
# tensor(3., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
def chain_rule_of_two(num):
    x = torch.tensor(num, dtype=torch.float32, requires_grad=True)
    print(x)
    
    y = x**2
    print(y)

    z = torch.sin(y)
    print(z)

    z.backward()
    print(x.grad)

# %%
chain_rule_of_two(4)
# Out:
# tensor(4., requires_grad=True)
# tensor(16., grad_fn=<PowBackward0>)
# tensor(-0.2879, grad_fn=<SinBackward0>)
# tensor(-7.6613)

# %%
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %% [markdown]
# ## IMP
# - by default, pytorch allows us to calculate gradient for leaf node only
# - use .backward() function only at the root node
# - if we use .backward() ,the particular variable should be a scalar (i.e. y.backward() only if y -> scalar)

# %% [markdown]
# ### clearing gradients
# - gradients have a property to accumulate if backpropogated multiple times

# %%
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()  ## without this gradients accumulate
# Out:
# tensor(0.)

# %% [markdown]
# ### disabling gradient tracking

# %% [markdown]
# - op1. requires_grad_(False)
# - op2. detach()
# - op3. torch.no_grad()

# %% [markdown]
# # OP 1

# %%
x = torch.tensor(3.0, requires_grad=True)
x
# Out:
# tensor(3., requires_grad=True)

# %%
y = x**2
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
x.requires_grad_(False)
x
# Out:
# tensor(3.)

# %%
y = x**2
y
# Out:
# tensor(9.)

# %%
# y.backward()  ## ERROR

# %% [markdown]
# # OP 2

# %%
x = torch.tensor(3.0, requires_grad=True)
x
# Out:
# tensor(3., requires_grad=True)

# %%
z = x.detach() 
## creates a variable 'z' with requires_grad=False

# %%
y1 = x** 2
y1
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y2 = z** 2
y2
# Out:
# tensor(9.)

# %%
y1.backward()
# y2.backward()  ## ERROR

# %% [markdown]
# # OP 3

# %%
x = torch.tensor(3.0, requires_grad=True)
x
# Out:
# tensor(3., requires_grad=True)

# %%
with torch.no_grad():  ## disables gradient tracking
    y = x** 2

# %%
y
# Out:
# tensor(9.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 y.backward()
#
# File D:\env\pytorch-cuda\Lib\site-packages\torch\_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File D:\env\pytorch-cuda\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File D:\env\pytorch-cuda\Lib\site-packages\torch\autograd\graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn
